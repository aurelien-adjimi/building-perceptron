# %%
# 1. Charger le modèle sauvegardé avec joblib
import joblib

modele = joblib.load('perceptron_best_model.pkl')

# 2. Recharger le jeu de données et refaire le découpage comme lors de l’entraînement
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

data = load_breast_cancer()
X = data.data
y = data.target

# IMPORTANT : toujours le même random_state et test_size que lors du fit !
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3. Faire des prédictions avec le modèle
predictions = modele.predict(X_test)

# 4. Évaluer et afficher les résultats
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print("Accuracy du modèle rechargé :", accuracy_score(y_test, predictions))
print("Matrice de confusion :\n", confusion_matrix(y_test, predictions))
print("Rapport de classification :\n", classification_report(y_test, predictions, target_names=data.target_names))
# Out:
# Accuracy du modèle rechargé : 0.9883040935672515
# Matrice de confusion :
#  [[ 62   1]
#  [  1 107]]
# Rapport de classification :
#                precision    recall  f1-score   support
#
#    malignant       0.98      0.98      0.98        63
#       benign       0.99      0.99      0.99       108
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171
